# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('../data/dataset.csv')

# %%
df.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price category
# 0      4313   9005     956               0             7  7559081.5    Basic
# 1      3653   2436     128               1             2  8085989.5   Luxury
# 2      2937   8852     135               1             9  5574642.1    Basic
# 3       659   7141     359               0             3  3232561.2    Basic
# 4      8435   2429     292               1             4  7055052.0   Luxury

# %%
# drop cityCode and cityPartRange
df.drop(['cityCode', 'cityPartRange'], axis=1, inplace=True)
labelEncoder = LabelEncoder()

df['category'] = labelEncoder.fit_transform(df['category'])
print(dict(zip(labelEncoder.classes_, labelEncoder.transform(labelEncoder.classes_))))
# Out:
# {'Basic': 0, 'Luxury': 1}

# %%
df.describe()
# Out:
#        squareMeters  numberOfRooms       hasYard       hasPool        floors  \
# count   10000.00000   10000.000000  10000.000000  10000.000000  10000.000000
# mean    49870.13120      50.358400      0.508700      0.496800     50.276300
# std     28774.37535      28.816696      0.499949      0.500015     28.889171
# min        89.00000       1.000000      0.000000      0.000000      1.000000
# 25%     25098.50000      25.000000      0.000000      0.000000     25.000000
# 50%     50105.50000      50.000000      1.000000      0.000000     50.000000
# 75%     74609.75000      75.000000      1.000000      1.000000     76.000000
# max     99999.00000     100.000000      1.000000      1.000000    100.000000
#
#        numPrevOwners         made    isNewBuilt  hasStormProtector  \
# count   10000.000000  10000.00000  10000.000000       10000.000000
# mean        5.521700   2005.48850      0.499100           0.499900
# std         2.856667      9.30809      0.500024           0.500025
# min         1.000000   1990.00000      0.000000           0.000000
# 25%         3.000000   1997.00000      0.000000           0.000000
# 50%         5.000000   2005.50000      0.000000           0.000000
# 75%         8.000000   2014.00000      1.000000           1.000000
# max        10.000000   2021.00000      1.000000           1.000000
#
#            basement        attic       garage  hasStorageRoom  hasGuestRoom  \
# count  10000.000000  10000.00000  10000.00000    10000.000000   10000.00000
# mean    5033.103900   5028.01060    553.12120        0.503000       4.99460
# std     2876.729545   2894.33221    262.05017        0.500016       3.17641
# min        0.000000      1.00000    100.00000        0.000000       0.00000
# 25%     2559.750000   2512.00000    327.75000        0.000000       2.00000
# 50%     5092.500000   5045.00000    554.00000        1.000000       5.00000
# 75%     7511.250000   7540.50000    777.25000        1.000000       8.00000
# max    10000.000000  10000.00000   1000.00000        1.000000      10.00000
#
#               price      category
# count  1.000000e+04  10000.000000
# mean   4.993448e+06      0.126500
# std    2.877424e+06      0.332429
# min    1.031350e+04      0.000000
# 25%    2.516402e+06      0.000000
# 50%    5.016180e+06      0.000000
# 75%    7.469092e+06      0.000000
# max    1.000677e+07      1.000000

# %%
#  scale squareMeters, made, basement, attic, garage, price
scaler = StandardScaler()
df[['squareMeters', 'made', 'basement', 'attic', 'garage', 'price']] = scaler.fit_transform(df[['squareMeters', 'made', 'basement', 'attic', 'garage', 'price']])

df.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  numPrevOwners  \
# 0      0.891562              3        0        1      63              8
# 1      1.073956             39        1        1      98              6
# 2      0.203033             58        0        1      19              8
# 3     -0.610092             47        0        0       6              4
# 4      0.714521             19        1        1      90              7
#
#        made  isNewBuilt  hasStormProtector  basement     attic    garage  \
# 0 -0.052484           0                  1 -0.250333  1.374130  1.537488
# 1  1.021904           1                  0 -0.479772 -0.895592 -1.622370
# 2  1.666537           0                  0 -0.728678  1.321265 -1.595657
# 3  0.699588           0                  1 -1.520589  0.730080 -0.740816
# 4 -1.664066           1                  0  1.182616 -0.898010 -0.996505
#
#    hasStorageRoom  hasGuestRoom     price  category
# 0               0             7  0.891687         0
# 1               1             2  1.074814         1
# 2               1             9  0.201994         0
# 3               0             3 -0.611997         0
# 4               1             4  0.716512         1

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping

earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')

x = df.drop('category', axis=1)
y = df['category']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# /opt/anaconda3/envs/summative/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,649 (14.25 KB)
#  Trainable params: 3,649 (14.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(x_train, y_train, epochs=100, batch_size=32, validation_data=(x_test, y_test), callbacks=[earlyStopping])
# Out:
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8215 - loss: 0.7892 - val_accuracy: 0.8720 - val_loss: 0.4232
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8663 - loss: 0.4447 - val_accuracy: 0.8720 - val_loss: 0.4073
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8653 - loss: 0.4422 - val_accuracy: 0.8720 - val_loss: 0.4045
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8848 - loss: 0.3899 - val_accuracy: 0.8720 - val_loss: 0.4077
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8751 - loss: 0.3889 - val_accuracy: 0.8720 - val_loss: 0.3894
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8722 - loss: 0.3922 - val_accuracy: 0.8720 - val_loss: 0.3593
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8739 - loss: 0.3709 - val_accuracy: 0.8720 - val_loss: 0.3216
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8758 - loss: 0.3358 - val_accuracy: 0.8720 - val_loss: 0.2924
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8803 - loss: 0.2948 - val_accuracy: 0.8720 - val_loss: 0.2348
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8728 - loss: 0.2626 - val_accuracy: 0.8720 - val_loss: 0.1995
# Epoch 11/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8759 - loss: 0.2251 - val_accuracy: 0.8720 - val_loss: 0.1846
# Epoch 12/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8772 - loss: 0.2124 - val_accuracy: 0.9610 - val_loss: 0.1407
# Epoch 13/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9131 - loss: 0.1762 - val_accuracy: 0.9665 - val_loss: 0.0990
# Epoch 14/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9462 - loss: 0.1291 - val_accuracy: 0.9655 - val_loss: 0.1018
# Epoch 15/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9561 - loss: 0.1080 - val_accuracy: 0.9930 - val_loss: 0.0425
# Epoch 16/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9738 - loss: 0.0722 - val_accuracy: 0.9815 - val_loss: 0.0506
# Epoch 17/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9839 - loss: 0.0521 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 18/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9910 - loss: 0.0315 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 19/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9922 - loss: 0.0250 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 20/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9932 - loss: 0.0220 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 21/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9942 - loss: 0.0209 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 22/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9954 - loss: 0.0141 - val_accuracy: 1.0000 - val_loss: 9.5703e-04
# Epoch 23/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9974 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 3.3894e-04
# Epoch 24/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9958 - loss: 0.0139 - val_accuracy: 1.0000 - val_loss: 5.6086e-04
# Epoch 25/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 2.9945e-04
# Epoch 26/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0031 - val_accuracy: 0.9985 - val_loss: 0.0039
# Epoch 27/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9960 - loss: 0.0155 - val_accuracy: 1.0000 - val_loss: 1.6106e-04
# Epoch 28/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9988 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 3.5145e-04
# Epoch 29/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9980 - loss: 0.0073 - val_accuracy: 1.0000 - val_loss: 4.6954e-04
# Epoch 30/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9981 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 2.8012e-04
# Epoch 31/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9958 - loss: 0.0186 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 32/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9992 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 4.8835e-04
# Epoch 33/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9985 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 7.9264e-05
# Epoch 34/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9991 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 1.5939e-04
# Epoch 35/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9992 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 6.1918e-05
# Epoch 36/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9987 - loss: 0.0052 - val_accuracy: 0.9910 - val_loss: 0.0230
# Epoch 37/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9938 - loss: 0.0208 - val_accuracy: 1.0000 - val_loss: 2.2582e-04
# Epoch 38/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9980 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 1.1187e-04
# Epoch 39/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9986 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 2.5845e-04
# Epoch 40/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9956 - loss: 0.0158 - val_accuracy: 1.0000 - val_loss: 1.5948e-04
# Epoch 41/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9980 - loss: 0.0054 - val_accuracy: 1.0000 - val_loss: 4.7761e-05
# Epoch 42/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9959 - loss: 0.0162 - val_accuracy: 1.0000 - val_loss: 3.0179e-04
# Epoch 43/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9978 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 1.7846e-04
# Epoch 44/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9980 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 45/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9903 - loss: 0.0339 - val_accuracy: 1.0000 - val_loss: 7.9936e-04
# Epoch 46/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9991 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 3.1711e-04
# Epoch 47/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9955 - loss: 0.0166 - val_accuracy: 1.0000 - val_loss: 3.0750e-04
# Epoch 48/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9962 - loss: 0.0191 - val_accuracy: 1.0000 - val_loss: 6.4306e-04
# Epoch 49/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9986 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 9.0493e-05
# Epoch 50/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 5.6074e-05
# Epoch 51/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9973 - loss: 0.0129 - val_accuracy: 1.0000 - val_loss: 1.9745e-04

# %%
model.evaluate(x_test, y_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.0296e-04
# [0.0001974496990442276, 1.0]

# %%
# 1.073956	39	1	1	98	6	1.021904	1	0	-0.479772	-0.895592	-1.622370	1	2	1.074814	1
testing = pd.DataFrame([[1.073956, 39, 1, 1, 98, 6, 1.021904, 1, 0, -0.479772, -0.895592, -1.622370, 1, 2, 1.074814]])
Prediction = model.predict(testing)[0][0]
PredictionText = 'Luxury' if Prediction > 0.5 else 'Basic'
print(Prediction, PredictionText)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 0.9999993 Luxury

# %%
import joblib

# Save the trained model to 'models/house_category.pkl'
joblib.dump(model.fit, '../models/house_category.pkl')
print("Model saved as 'house_category.pkl' in the 'models' folder.")
# Out:
# Model saved as 'house_category.pkl' in the 'models' folder.
